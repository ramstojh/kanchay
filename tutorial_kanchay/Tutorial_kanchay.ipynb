# %%
from kanchay import kan
# %matplotlib inline
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
starid='Gaia DR2 2395082091638750848'
x, y, yerr = kan.search_lk(starid, mission='TESS', store='yes')
# Out:
# Started querying MAST for observations within 0.0001 arcsec arcsec of objectname='Gaia DR2 2395082091638750848'.
# MAST found 1 observations. Now querying MAST for the corresponding data products.
# MAST found 1 matching data products.
#   0%|          | 0/1 [00:00<?, ?it/s]File found in local cache.
# Opening /home/ramstojh/.lightkurve-cache/mastDownload/TESS/tess2018234235059-s0002-0000000434096244-0121-s/tess2018234235059-s0002-0000000434096244-0121-s_lc.fits.
# Detected filetype: 'TessLightCurve'.
# Ignoring 1038 rows with NaN times
# 2% (399/18699) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 02 2018   SPOC     120   434096244      0.0
# 100%|██████████| 1/1 [00:01<00:00,  1.46s/it]

# %%
import matplotlib.pyplot as plt
plt.scatter(x[0][2000:8500], y[0][2000:8500])

# %%
kan.rotation_calc(x[0][2000:8500], y[0][2000:8500], yerr[0][2000:8500], gp='yes')
# Out:
# 100%|██████████| 1000/1000 [00:02<00:00, 400.15it/s]
# optimizing logp for variables: [f, log_dQ, log_Q0, log_period, sigma_rot, rho, sigma, log_jitter, mean]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='115' class='' max='115' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [115/115 00:00<00:00 logp = nan]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: -1717.1592045795453 -> nan
# final logp not finite, returning initial point
# this suggests that something is wrong with the model
# Multiprocess sampling (2 chains in 8 jobs)
# NUTS: [f, log_dQ, log_Q0, log_period, sigma_rot, rho, sigma, log_jitter, mean]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:27<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 28 seconds.
#          LS       ACF       PDM   err_PDM        GP       +GP       -GP
# 0  1.584104  1.579168  1.586486  0.070106  1.584944  0.005766  0.005943
